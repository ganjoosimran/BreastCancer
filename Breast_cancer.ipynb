# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt #matplotlib is used for plot the graphs,
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
data=pd.read_csv(r"D:\Notes\breast-cancer.xls")
data.head()
data.shape
# Out:
# (569, 33)

# %%
x=data[['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean','radius_se','perimeter_se', 'area_se','compactness_se', 'concave points_se','radius_worst','perimeter_worst','compactness_worst','concave points_worst','texture_worst','area_worst']]
y=data[['diagnosis']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.metrics import accuracy_score

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
predict = model.predict(x_test)
accuracy=accuracy_score(predict,y_test)
print(accuracy)
# Out:
# 0.935672514619883
# C:\Users\ganjo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
x_train.head()
# Out:
#      radius_mean  perimeter_mean  area_mean  compactness_mean  \
# 249        11.52           73.87      406.3           0.07808
# 58         13.05           82.61      527.2           0.03789
# 476        14.20           92.41      618.4           0.11080
# 529        12.07           77.83      445.2           0.09009
# 422        11.61           75.46      408.2           0.11680
#
#      concave points_mean  radius_se  perimeter_se  area_se  compactness_se  \
# 249             0.029290     0.2562         1.686    18.62        0.012280
# 58              0.004167     0.4040         2.595    32.96        0.008593
# 476             0.030580     0.3478         2.749    31.01        0.032880
# 529             0.027980     0.2513         1.714    18.54        0.011530
# 422             0.044970     0.2456         1.667    15.89        0.020050
#
#      concave points_se  radius_worst  perimeter_worst  compactness_worst  \
# 249           0.010060         12.65            80.88            0.15820
# 58            0.004167         14.23            90.24            0.06191
# 476           0.013500         16.45           112.10            0.34290
# 529           0.007986         13.45            86.92            0.16320
# 422           0.013040         12.64            81.93            0.21700
#
#      concave points_worst  texture_worst  area_worst
# 249               0.09608          21.19       491.8
# 58                0.01111          22.25       624.1
# 476               0.13390          27.26       828.5
# 529               0.07393          15.77       549.9
# 422               0.11050          19.67       475.7

# %%
pred=model.predict(x_train)
pred[:5]
# Out:
# array(['B', 'B', 'B', 'B', 'B'], dtype=object)

# %%
x_train.iloc[0:25, :]
# Out:
#      radius_mean  perimeter_mean  area_mean  compactness_mean  \
# 249       11.520           73.87      406.3           0.07808
# 58        13.050           82.61      527.2           0.03789
# 476       14.200           92.41      618.4           0.11080
# 529       12.070           77.83      445.2           0.09009
# 422       11.610           75.46      408.2           0.11680
# 192        9.720           60.73      288.1           0.02344
# 527       12.340           78.94      468.5           0.06307
# 472       14.920           96.45      686.9           0.08549
# 101        6.981           43.79      143.5           0.07568
# 540       11.540           74.65      402.9           0.11200
#
#      concave points_mean  radius_se  perimeter_se  area_se  compactness_se  \
# 249             0.029290     0.2562        1.6860   18.620        0.012280
# 58              0.004167     0.4040        2.5950   32.960        0.008593
# 476             0.030580     0.3478        2.7490   31.010        0.032880
# 529             0.027980     0.2513        1.7140   18.540        0.011530
# 422             0.044970     0.2456        1.6670   15.890        0.020050
# 192             0.000000     0.3539        2.2300   21.690        0.006736
# 527             0.026470     0.1166        0.7714    8.955        0.009169
# 472             0.032210     0.2446        1.8260   23.310        0.017700
# 101             0.000000     0.2241        1.5530    9.833        0.010840
# 540             0.025940     0.2784        1.6280   20.860        0.041120
#
#      concave points_se  radius_worst  perimeter_worst  compactness_worst  \
# 249           0.010060        12.650            80.88            0.15820
# 58            0.004167        14.230            90.24            0.06191
# 476           0.013500        16.450           112.10            0.34290
# 529           0.007986        13.450            86.92            0.16320
# 422           0.013040        12.640            81.93            0.21700
# 192           0.000000         9.968            62.25            0.02729
# 527           0.005740        13.610            87.22            0.20740
# 472           0.008399        17.180           112.00            0.27910
# 101           0.000000         7.930            50.41            0.12020
# 540           0.014940        12.260            78.78            0.21180
#
#      concave points_worst  texture_worst  area_worst
# 249               0.09608          21.19       491.8
# 58                0.01111          22.25       624.1
# 476               0.13390          27.26       828.5
# 529               0.07393          15.77       549.9
# 422               0.11050          19.67       475.7
# 192               0.00000          20.83       303.8
# 527               0.10700          19.27       564.9
# 472               0.11470          18.22       906.6
# 101               0.00000          19.54       185.2
# 540               0.06918          19.68       457.8

# %%
y_train.iloc[0:25, :]
# Out:
#     diagnosis
# 249         B
# 58          B
# 476         B
# 529         B
# 422         B
# 192         B
# 527         B
# 472         B
# 101         B
# 540         B
# 104         B
# 523         B
# 318         B
# 375         B
# 18          M
# 168         M
# 361         B
# 121         M
# 315         B
# 402         B
# 383         B
# 465         B
# 566         M
# 260         M
# 80          B

# %%
pred=model.predict(x_train.iloc[0:25, :])
pred
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B'],
#       dtype=object)
